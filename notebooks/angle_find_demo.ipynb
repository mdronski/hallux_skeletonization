# %%
from src.angle_find import find_lines
from src.data_load import load_single, load_all
from src.skeletonize import skeletonize
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = load_single(0)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 0.9736842105263157, theta0.4078558883607801, threshold80

# %%
img = load_single(1)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 0.9736842105263157, theta0.31967083141790875, threshold80

# %%
img = load_single(2)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 1.131578947368421, theta0.23148577447503738, threshold80

# %%
img = load_single(3)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 0.8947368421052632, theta0.29762456718219094, threshold80

# %%
img = load_single(4)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 1.0526315789473684, theta0.27557830294647306, threshold80

# %%
img = load_single(5)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 1.131578947368421, theta0.29762456718219094, threshold80

# %%
img = load_single(6)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 2.0, theta0.27557830294647306, threshold80

# %%
img = load_single(7)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 1.131578947368421, theta0.29762456718219094, threshold80

# %%
img = load_single(8)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 0.8157894736842105, theta0.5621797380108051, threshold80

# %%
img = load_single(9)
skeleton = skeletonize(img, True)
x = find_lines(skeleton, True)
# Out:
# rho: 1.0526315789473684, theta0.25353203871075525, threshold80
